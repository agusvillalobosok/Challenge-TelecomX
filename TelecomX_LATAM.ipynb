# %% [markdown]
# <a href="https://colab.research.google.com/github/agusvillalobosok/Challenge-TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
json = pd.read_json('/content/TelecomX_Data.json')
json.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# Normalizando el archivo

import json

with open('/content/TelecomX_Data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
df = pd.json_normalize(data)
df
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
datos = pd.DataFrame(df)
datos.head(5)
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
datos.dtypes
# Out:
# customerID                    object
# Churn                         object
# customer.gender               object
# customer.SeniorCitizen         int64
# customer.Partner              object
# customer.Dependents           object
# customer.tenure                int64
# phone.PhoneService            object
# phone.MultipleLines           object
# internet.InternetService      object
# internet.OnlineSecurity       object
# internet.OnlineBackup         object
# internet.DeviceProtection     object
# internet.TechSupport          object
# internet.StreamingTV          object
# internet.StreamingMovies      object
# account.Contract              object
# account.PaperlessBilling      object
# account.PaymentMethod         object
# account.Charges.Monthly      float64
# account.Charges.Total         object
# dtype: object

# %%
# revisando inconsistencias

for col in df.columns:
    print(f"Valores únicos en la columna '{col}':")
    print(pd.unique(df[col]))
    print('-' * 40)
# Out:
# Valores únicos en la columna 'customerID':
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# ----------------------------------------
# Valores únicos en la columna 'Churn':
# ['No' 'Yes' '']
# ----------------------------------------
# Valores únicos en la columna 'customer.gender':
# ['Female' 'Male']
# ----------------------------------------
# Valores únicos en la columna 'customer.SeniorCitizen':
# [0 1]
# ----------------------------------------
# Valores únicos en la columna 'customer.Partner':
# ['Yes' 'No']
# ----------------------------------------
# Valores únicos en la columna 'customer.Dependents':
# ['Yes' 'No']
# ----------------------------------------
# Valores únicos en la columna 'customer.tenure':
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
# ...

# %% [markdown]
# #🔧 Transformación

# %%
# agregando una columna con el valor del costo diario

df['account.Charges.Daily'] = df['account.Charges.Monthly'] / 30

# %%
df
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
# Estandarización de datos

columnas_a_convertir = ['Churn', 'customer.Partner', 'customer.Dependents', 'phone.PhoneService',
                        'phone.MultipleLines','internet.OnlineSecurity','internet.OnlineBackup',
                        'internet.DeviceProtection','internet.TechSupport','internet.StreamingTV',
                        'internet.StreamingMovies','account.PaperlessBilling']

df[columnas_a_convertir] = df[columnas_a_convertir].replace({'Yes': 1, 'No': 0, 'No internet service': 0, 'No phone service': 0})
# Out:
# /tmp/ipython-input-12-1103727873.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[columnas_a_convertir] = df[columnas_a_convertir].replace({'Yes': 1, 'No': 0, 'No internet service': 0, 'No phone service': 0})

# %%
df.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen  customer.Partner  \
# 0  0002-ORFBO     0          Female                       0                 1
# 1  0003-MKNFE     0            Male                       0                 0
# 2  0004-TLHLJ     1            Male                       0                 0
# 3  0011-IGKFF     1            Male                       1                 1
# 4  0013-EXCHZ     1          Female                       1                 1
#
#    customer.Dependents  customer.tenure  phone.PhoneService  \
# 0                    1                9                   1
# 1                    0                9                   1
# 2                    0                4                   1
# 3                    0               13                   1
# 4                    0                3                   1
#
#    phone.MultipleLines internet.InternetService  ...  \
# 0                    0                      DSL  ...
# ...

# %%
for col in df.columns:
    print(f"Valores únicos en la columna '{col}':")
    print(pd.unique(df[col]))
    print('-' * 40)
# Out:
# Valores únicos en la columna 'customerID':
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# ----------------------------------------
# Valores únicos en la columna 'Churn':
# [0 1 '']
# ----------------------------------------
# Valores únicos en la columna 'customer.gender':
# ['Female' 'Male']
# ----------------------------------------
# Valores únicos en la columna 'customer.SeniorCitizen':
# [0 1]
# ----------------------------------------
# Valores únicos en la columna 'customer.Partner':
# [1 0]
# ----------------------------------------
# Valores únicos en la columna 'customer.Dependents':
# [1 0]
# ----------------------------------------
# Valores únicos en la columna 'customer.tenure':
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# ...

# %%
df_columnas = df.columns
df_columnas
# Out:
# Index(['customerID', 'Churn', 'customer.gender', 'customer.SeniorCitizen',
#        'customer.Partner', 'customer.Dependents', 'customer.tenure',
#        'phone.PhoneService', 'phone.MultipleLines', 'internet.InternetService',
#        'internet.OnlineSecurity', 'internet.OnlineBackup',
#        'internet.DeviceProtection', 'internet.TechSupport',
#        'internet.StreamingTV', 'internet.StreamingMovies', 'account.Contract',
#        'account.PaperlessBilling', 'account.PaymentMethod',
#        'account.Charges.Monthly', 'account.Charges.Total',
#        'account.Charges.Daily'],
#       dtype='object')

# %%
df = df.rename(columns={
    'customerID': "ID_cliente"
    , 'Churn': "Baja_cliente"
    , 'customer.gender': "Género"
    , 'customer.SeniorCitizen': "Jubilado"
    , 'customer.Partner': "Pareja"
    , 'customer.Dependents': "Hijos"
    , 'customer.tenure': "Meses_de_Contrato"
    , 'phone.PhoneService': "Servicio_Telefónico"
    , 'phone.MultipleLines': "Multi_Lineas"
    , 'internet.InternetService': "Servicio_Internet"
    , 'internet.OnlineSecurity': "Seguridad_Online"
    , 'internet.OnlineBackup': "Servicio_de_Backup"
    , 'internet.DeviceProtection': "Proteccion_de_Dispositivo"
    , 'internet.TechSupport': "Soporte_Tecnico_Full"
    , 'internet.StreamingTV': "Stream_TV"
    , 'internet.StreamingMovies': "Stream_Movies"
    , 'account.Contract': "Contrato"
    , 'account.PaperlessBilling': "Factura_Online"
    , 'account.PaymentMethod': "Forma_de_Pago"
    , 'account.Charges.Monthly': "Tarifa_Mensual_Cliente"
    , 'account.Charges.Total': "Total_Tarifas_Cliente"
    , 'account.Charges.Daily': "Tarifa_por_Dia"
})

# %%
df.head()
# Out:
#    ID_cliente Baja_cliente  Género  Jubilado  Pareja  Hijos  \
# 0  0002-ORFBO            0  Female         0       1      1
# 1  0003-MKNFE            0    Male         0       0      0
# 2  0004-TLHLJ            1    Male         0       0      0
# 3  0011-IGKFF            1    Male         1       1      0
# 4  0013-EXCHZ            1  Female         1       1      0
#
#    Meses_de_Contrato  Servicio_Telefónico  Multi_Lineas Servicio_Internet  \
# 0                  9                    1             0               DSL
# 1                  9                    1             1               DSL
# 2                  4                    1             0       Fiber optic
# 3                 13                    1             0       Fiber optic
# 4                  3                    1             0       Fiber optic
#
#    ...  Proteccion_de_Dispositivo  Soporte_Tecnico_Full  Stream_TV  \
# 0  ...                          0                     1          1
# ...

# %%
evasion = df
evasion.drop(columns=["ID_cliente","Meses_de_Contrato","Servicio_Telefónico","Multi_Lineas","Servicio_Internet",
                      "Seguridad_Online","Seguridad_Online","Servicio_de_Backup","Proteccion_de_Dispositivo",
                      "Soporte_Tecnico_Full","Stream_TV","Stream_Movies","Factura_Online",
                      "Tarifa_Mensual_Cliente","Total_Tarifas_Cliente","Tarifa_por_Dia"])
# Out:
#      Baja_cliente  Género  Jubilado  Pareja  Hijos        Contrato  \
# 0               0  Female         0       1      1        One year
# 1               0    Male         0       0      0  Month-to-month
# 2               1    Male         0       0      0  Month-to-month
# 3               1    Male         1       1      0  Month-to-month
# 4               1  Female         1       1      0  Month-to-month
# ...           ...     ...       ...     ...    ...             ...
# 7262            0  Female         0       0      0        One year
# 7263            1    Male         0       1      0  Month-to-month
# 7264            0    Male         0       0      0  Month-to-month
# 7265            0    Male         0       1      1        Two year
# 7266            0    Male         0       1      1        Two year
#
#          Forma_de_Pago
# 0         Mailed check
# 1         Mailed check
# 2     Electronic check
# 3     Electronic check
# 4         Mailed check
# ...

# %%
evasion.head()
# Out:
#    ID_cliente Baja_cliente  Género  Jubilado  Pareja  Hijos  \
# 0  0002-ORFBO            0  Female         0       1      1
# 1  0003-MKNFE            0    Male         0       0      0
# 2  0004-TLHLJ            1    Male         0       0      0
# 3  0011-IGKFF            1    Male         1       1      0
# 4  0013-EXCHZ            1  Female         1       1      0
#
#    Meses_de_Contrato  Servicio_Telefónico  Multi_Lineas Servicio_Internet  \
# 0                  9                    1             0               DSL
# 1                  9                    1             1               DSL
# 2                  4                    1             0       Fiber optic
# 3                 13                    1             0       Fiber optic
# 4                  3                    1             0       Fiber optic
#
#    ...  Proteccion_de_Dispositivo  Soporte_Tecnico_Full  Stream_TV  \
# 0  ...                          0                     1          1
# ...

# %%
evasion_filtrado = evasion[evasion["Baja_cliente"] == 1]

# %%
df_evasion = pd.DataFrame(evasion_filtrado)
df_evasion
# Out:
#       ID_cliente Baja_cliente  Género  Jubilado  Pareja  Hijos  \
# 2     0004-TLHLJ            1    Male         0       0      0
# 3     0011-IGKFF            1    Male         1       1      0
# 4     0013-EXCHZ            1  Female         1       1      0
# 18    0022-TCJCI            1    Male         1       0      0
# 19    0023-HGHWL            1    Male         1       0      0
# ...          ...          ...     ...       ...     ...    ...
# 7243  9961-JBNMK            1    Male         1       0      0
# 7246  9965-YOKZB            1    Male         1       0      0
# 7260  9985-MWVIX            1  Female         0       0      0
# 7261  9986-BONCE            1  Female         0       0      0
# 7263  9992-RRAMN            1    Male         0       1      0
#
#       Meses_de_Contrato  Servicio_Telefónico  Multi_Lineas Servicio_Internet  \
# 2                     4                    1             0       Fiber optic
# ...

# %%
df_evasion1 = df_evasion['Total_Tarifas_Cliente'].dropna()
df_evasion1 = pd.DataFrame(df_evasion1)

# %%
# Estandarización de datos

columnas_a_convertir_evasion = ["Contrato","Forma_de_Pago","Género"]

df_evasion[columnas_a_convertir_evasion] = df_evasion[columnas_a_convertir_evasion].replace({"Electronic check":"Factura electrónica","Mailed check":"Factura por correo","Bank transfer (automatic)":"Débito automático","Credit card (automatic)":"Tarjeta de crédito (automático)",'Month-to-month': "Mensual", 'One year': "Anual", 'Two year': "Bianual", 'Female': "Femenino","Male":"Masculino"})

# %%
df_evasion_count = pd.DataFrame(df_evasion.value_counts())
df_evasion_count
# Out:
#                                                                                                                                                                                                                                                                                                                                                              count
# ID_cliente Baja_cliente Género    Jubilado Pareja Hijos Meses_de_Contrato Servicio_Telefónico Multi_Lineas Servicio_Internet Seguridad_Online Servicio_de_Backup Proteccion_de_Dispositivo Soporte_Tecnico_Full Stream_TV Stream_Movies Contrato Factura_Online Forma_de_Pago                   Tarifa_Mensual_Cliente Total_Tarifas_Cliente Tarifa_por_Dia
# ...

# %%
6### Gráfico de torta Distribución de EVASIÓN en GÉNERO, JUBILADO, HIJOS Y PAREJA. ###

def autopct_func(pct, all_vals):
    absolute = int(round(pct / 100. * sum(all_vals)))
    return f'{pct:.1f}%\n({absolute})'

def gen_graf_evasion_GJHP(colormap):
  # Conteos
  genero_counts = df_evasion["Género"].value_counts()
  jubilado_counts = df_evasion["Jubilado"].value_counts()
  pareja_counts = df_evasion["Pareja"].value_counts()
  hijos_counts = df_evasion["Hijos"].value_counts()

  # Colores
  num_categorias = len(genero_counts)
  colormap = plt.get_cmap(colormap)  # o 'Pastel1', 'tab20', 'Accent', etc.
  colores = colormap(np.linspace(0, 1, num_categorias))



  # Subplots
  fig, axes = plt.subplots(2, 2, figsize=(12, 7))
  axes = axes.flatten()

  # Gráfico 1: Género
  axes[0].pie(
      genero_counts.values,
      labels=genero_counts.index,
      autopct=lambda pct: autopct_func(pct, genero_counts.values),
      startangle=90,
      colors=colores
  )
  axes[0].set_title('Distribución de Género\npara Clientes con Baja', fontfamily="sans-serif", fontsize=16)

  # Gráfico 2: Jubilado
  axes[1].pie(
      jubilado_counts.values,
      labels=jubilado_counts.index,
      autopct=lambda pct: autopct_func(pct, jubilado_counts.values),
      startangle=90,
      colors=colores
  )
  axes[1].set_title('Distribución de Jubilado\npara Clientes con Baja', fontfamily="sans-serif", fontsize=16)

  # Gráfico 3: Pareja
  axes[2].pie(
      pareja_counts.values,
      labels=pareja_counts.index,
      autopct=lambda pct: autopct_func(pct, pareja_counts.values),
      startangle=90,
      colors=colores
  )
  axes[2].set_title('Distribución de Pareja\npara Clientes con Baja', fontfamily="sans-serif", fontsize=16)

  # Gráfico 4: Hijos
  axes[3].pie(
      hijos_counts.values,
      labels=hijos_counts.index,
      autopct=lambda pct: autopct_func(pct, hijos_counts.values),
      startangle=90,
      colors=colores
  )
  axes[3].set_title('Distribución de Hijos\npara Clientes con Baja', fontfamily="sans-serif", fontsize=16)


  # Título inferior
  fig.text(0.5, 0.01, '0 = No es/No tiene\n\n1 = Sí es/Sí tiene', ha='center', fontsize=12)

  # Mostrar gráfico
  plt.show()

# %%
### Gráfico de FORMA DE PAGO Y CONTRATO ###

def autopct_func(pct, all_vals):
        absolute = int(round(pct/100.*sum(all_vals)))
        return f"{pct:.1f}%\n({absolute})"
def gen_graf_evasion_Pagocontrato(colormap):

  # Conteos
  contrato_counts = df_evasion["Contrato"].value_counts()
  F_Pago_counts = df_evasion["Forma_de_Pago"].value_counts()

  # Colores
  num_categorias = len(F_Pago_counts)
  colormap = plt.get_cmap(colormap)  # o 'Pastel1', 'tab20', 'Accent', etc.
  colores = colormap(np.linspace(0, 1, num_categorias))

  # Crear subplots
  fig, axes = plt.subplots(1, 2, figsize=(12, 7))
  axes = axes.flatten()

  # Gráfico de Forma de Pago
  axes[0].pie(
    F_Pago_counts.values,
    labels=F_Pago_counts.index,
    autopct=lambda pct: autopct_func(pct, F_Pago_counts.values),
    startangle=90,
    colors=colores

)
  axes[0].set_title('Distribución de la forma de pago\npara Clientes que pidieron la baja', fontfamily="sans-serif", fontsize=14)

  # Gráfico de Contrato
  axes[1].pie(
    contrato_counts.values,
    labels=contrato_counts.index,
    autopct=lambda pct: autopct_func(pct, contrato_counts.values),
    startangle=90,
    colors=colores
)
  axes[1].set_title('Distribución del tipo de contrato\nde los Clientes que pidieron la baja', fontfamily="sans-serif", fontsize=14)


  plt.show()

# %%
### Gráfico de barras EVASIÓN DE CLIENTES ###

def gen_graf_evasion(palette):

  # Convertimos a DataFrame para usar Seaborn
  df_baja = baja_cliente_graf.reset_index()
  df_baja.columns = ["Situación", "Cantidad"]

  # Crear gráfico
  plt.figure(figsize=(12, 7))
  ax = sns.barplot(
      data=df_baja,
      hue="Situación",
      x="Cantidad",
      palette=palette,
      orient="h",
      width=0.4
  )

  # Estilo
  ax.set_title("Situación actual TelecomX", loc="left", fontsize=18, fontfamily="sans-serif")
  ax.set_xlabel("")  # sin etiqueta en el eje x
  ax.set_ylabel("")  # sin etiqueta en el eje y
  ax.spines['top'].set_visible(False)
  ax.spines['right'].set_visible(False)
  ax.spines['left'].set_visible(False)
  ax.spines['bottom'].set_visible(False)
  ax.tick_params(axis="y", labelsize=14)
  ax.tick_params(axis="x", bottom=False, labelbottom=False)

  # Etiquetas con valores
  for p in ax.patches:
      width = p.get_width()
      ax.text(
          width + 0.5,
          p.get_y() + p.get_height() / 2,
          f'{int(width)}',
          ha='left', va='center', fontsize=14
      )


  plt.savefig("/content/evasion_de_clientes.png", transparent=False, dpi=300, bbox_inches="tight")
  plt.show()

# %%
df.head()
# Out:
#    ID_cliente Baja_cliente  Género  Jubilado  Pareja  Hijos  \
# 0  0002-ORFBO            0  Female         0       1      1
# 1  0003-MKNFE            0    Male         0       0      0
# 2  0004-TLHLJ            1    Male         0       0      0
# 3  0011-IGKFF            1    Male         1       1      0
# 4  0013-EXCHZ            1  Female         1       1      0
#
#    Meses_de_Contrato  Servicio_Telefónico  Multi_Lineas Servicio_Internet  \
# 0                  9                    1             0               DSL
# 1                  9                    1             1               DSL
# 2                  4                    1             0       Fiber optic
# 3                 13                    1             0       Fiber optic
# 4                  3                    1             0       Fiber optic
#
#    ...  Proteccion_de_Dispositivo  Soporte_Tecnico_Full  Stream_TV  \
# 0  ...                          0                     1          1
# ...

# %%
df_evasion.head()
# Out:
#     ID_cliente Baja_cliente     Género  Jubilado  Pareja  Hijos  \
# 2   0004-TLHLJ            1  Masculino         0       0      0
# 3   0011-IGKFF            1  Masculino         1       1      0
# 4   0013-EXCHZ            1   Femenino         1       1      0
# 18  0022-TCJCI            1  Masculino         1       0      0
# 19  0023-HGHWL            1  Masculino         1       0      0
#
#     Meses_de_Contrato  Servicio_Telefónico  Multi_Lineas Servicio_Internet  \
# 2                   4                    1             0       Fiber optic
# 3                  13                    1             0       Fiber optic
# 4                   3                    1             0       Fiber optic
# 18                 45                    1             0               DSL
# 19                  1                    0             0               DSL
#
#     ...  Proteccion_de_Dispositivo  Soporte_Tecnico_Full  Stream_TV  \
# ...

# %%
filtro_clientes = df[df["Baja_cliente"] == 0]

# %%
df_clientes = pd.DataFrame(filtro_clientes)
df_clientes
# Out:
#       ID_cliente Baja_cliente  Género  Jubilado  Pareja  Hijos  \
# 0     0002-ORFBO            0  Female         0       1      1
# 1     0003-MKNFE            0    Male         0       0      0
# 5     0013-MHZWF            0  Female         0       0      1
# 6     0013-SMEOE            0  Female         1       1      0
# 7     0014-BMAQU            0    Male         0       1      0
# ...          ...          ...     ...       ...     ...    ...
# 7259  9979-RGMZT            0  Female         0       0      0
# 7262  9987-LUTYD            0  Female         0       0      0
# 7264  9992-UJOEL            0    Male         0       0      0
# 7265  9993-LHIEB            0    Male         0       1      1
# 7266  9995-HOTOH            0    Male         0       1      1
#
#       Meses_de_Contrato  Servicio_Telefónico  Multi_Lineas Servicio_Internet  \
# 0                     9                    1             0               DSL
# ...

# %%
df_clientes['Total_Tarifas_Cliente'].dropna(inplace=True)

# %%
df_clientes1 = df_clientes['Total_Tarifas_Cliente'].astype(str).mask(df_clientes['Total_Tarifas_Cliente'].astype(str).str.match(r'^\s*$')).astype(float)
df_clientes1 = pd.DataFrame(df_clientes1)
df_clientes1['Total_Tarifas_Cliente'] = pd.to_numeric(df_clientes1['Total_Tarifas_Cliente'], errors='coerce')

# %%
df_clientes1 = df_clientes1.astype(float)
df_clientes1
# Out:
#       Total_Tarifas_Cliente
# 0                    593.30
# 1                    542.40
# 5                    571.45
# 6                   7904.25
# 7                   5377.80
# ...                     ...
# 7259                 633.45
# 7262                 742.90
# 7264                  92.75
# 7265                4627.65
# 7266                3707.60
#
# [5174 rows x 1 columns]

# %%
eva_total_tarifas = pd.DataFrame(df_evasion.reset_index(drop=True) )
eva_total_tarifas
# Out:
#       ID_cliente Baja_cliente     Género  Jubilado  Pareja  Hijos  \
# 0     0004-TLHLJ            1  Masculino         0       0      0
# 1     0011-IGKFF            1  Masculino         1       1      0
# 2     0013-EXCHZ            1   Femenino         1       1      0
# 3     0022-TCJCI            1  Masculino         1       0      0
# 4     0023-HGHWL            1  Masculino         1       0      0
# ...          ...          ...        ...       ...     ...    ...
# 1864  9961-JBNMK            1  Masculino         1       0      0
# 1865  9965-YOKZB            1  Masculino         1       0      0
# 1866  9985-MWVIX            1   Femenino         0       0      0
# 1867  9986-BONCE            1   Femenino         0       0      0
# 1868  9992-RRAMN            1  Masculino         0       1      0
#
#       Meses_de_Contrato  Servicio_Telefónico  Multi_Lineas Servicio_Internet  \
# 0                     4                    1             0       Fiber optic
# ...

# %%
clie_total_tarifas = pd.DataFrame(df_clientes["Total_Tarifas_Cliente"].reset_index(drop=True))
clie_total_tarifas
# Out:
#      Total_Tarifas_Cliente
# 0                    593.3
# 1                    542.4
# 2                   571.45
# 3                  7904.25
# 4                   5377.8
# ...                    ...
# 5169                633.45
# 5170                 742.9
# 5171                 92.75
# 5172               4627.65
# 5173                3707.6
#
# [5174 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def gen_graf_gastado_barras():

    clie_total_tarifas['Total_Tarifas_Cliente'] = pd.to_numeric(
        clie_total_tarifas['Total_Tarifas_Cliente'], errors='coerce'
    )

    # Eliminar valores no válidos
    clie_total_tarifas.dropna(subset=['Total_Tarifas_Cliente'], inplace=True)


    max_y = clie_total_tarifas["Total_Tarifas_Cliente"].max()
    yticks = np.arange(0, max_y + 1000, 1000)


    plt.figure(figsize=(12, 7))
    plt.bar(clie_total_tarifas.index, clie_total_tarifas["Total_Tarifas_Cliente"],
            color="green", label="Total Tarifas Cliente")


    plt.yticks(yticks)
    plt.grid(True, axis='y')
    plt.xlabel("Usuarios activos")
    plt.ylabel("Total Tarifas Cliente")
    plt.title("Total Tarifas Cliente - Gráfico de Barras")
    plt.legend()
    plt.tight_layout()
    plt.savefig("/content/graf-gasto-barras.png", transparent=False, dpi=300, bbox_inches="tight")
    plt.show()

# %%
def gen_graf_gastado3():

    eva_total_tarifas['Total_Tarifas_Cliente'] = pd.to_numeric(
        eva_total_tarifas['Total_Tarifas_Cliente'], errors='coerce'
    )
    clie_total_tarifas['Total_Tarifas_Cliente'] = pd.to_numeric(
        clie_total_tarifas['Total_Tarifas_Cliente'], errors='coerce'
    )


    eva_total_tarifas.dropna(subset=['Total_Tarifas_Cliente'], inplace=True)
    clie_total_tarifas.dropna(subset=['Total_Tarifas_Cliente'], inplace=True)


    max_y = max(
        eva_total_tarifas["Total_Tarifas_Cliente"].max(),
        clie_total_tarifas["Total_Tarifas_Cliente"].max()
    )


    yticks = np.arange(0, max_y + 1000, 1000)


    plt.figure(figsize=(12, 7))
    plt.bar(
        eva_total_tarifas.index,
        eva_total_tarifas["Total_Tarifas_Cliente"],
        label="Evasión",
        color="red"
    )


    plt.yticks(yticks)
    plt.grid(True, axis='y')
    plt.xlabel("Cantidad de evasores")
    plt.ylabel("Total Tarifas Cliente")
    plt.title("Comparación de Total Tarifas Cliente")
    plt.legend()
    plt.tight_layout()
    plt.savefig("/content/graf-gasto-barras3.png", transparent=False, dpi=300, bbox_inches="tight")
    plt.show()

# %%
def gen_graf_curva():

  # Crear listas de valores estadísticos
  lista_clientes = [
      clie_total_tarifas.describe().loc["min", "Total_Tarifas_Cliente"],
      clie_total_tarifas.describe().loc["25%", "Total_Tarifas_Cliente"],
      clie_total_tarifas.describe().loc["50%", "Total_Tarifas_Cliente"],
      clie_total_tarifas.describe().loc["75%", "Total_Tarifas_Cliente"],
      clie_total_tarifas.describe().loc["max", "Total_Tarifas_Cliente"],
  ]

  lista_eva = [
      eva_total_tarifas.describe().loc["min", "Total_Tarifas_Cliente"],
      eva_total_tarifas.describe().loc["25%", "Total_Tarifas_Cliente"],
      eva_total_tarifas.describe().loc["50%", "Total_Tarifas_Cliente"],
      eva_total_tarifas.describe().loc["75%", "Total_Tarifas_Cliente"],
      eva_total_tarifas.describe().loc["max", "Total_Tarifas_Cliente"],
  ]


  plt.figure(figsize=(10, 6))
  plt.plot(lista_eva, marker="o", label="Evasión")
  plt.plot(lista_clientes, marker="o", label="Clientes")

  plt.title("Curva: tarifa total de clientes y evasores")
  plt.xticks(range(5), ["min", "25%", "50%", "75%", "max"])
  plt.legend()

  # Anotar valores sobre los puntos
  for i, val in enumerate(lista_eva):
      plt.text(i, val + max(lista_eva)*0.02, f"{val:,.0f}", ha='center', color='red')
  for i, val in enumerate(lista_clientes):
      plt.text(i, val + max(lista_clientes)*0.02, f"{val:,.0f}", ha='center', color='green')

  plt.grid(True, axis='y')
  plt.tight_layout()
  plt.savefig("/content/graf-curva.png", transparent=False, dpi=300, bbox_inches="tight")
  plt.show()

# %%
df_evasion1.reset_index(drop=True)
df_evasion1 = df_evasion1.astype(float)
df_evasion1.describe()
# Out:
#        Total_Tarifas_Cliente
# count            1869.000000
# mean             1531.796094
# std              1890.822994
# min                18.850000
# 25%               134.500000
# 50%               703.550000
# 75%              2331.300000
# max              8684.800000

# %%
def gen_graf_media_tarifa():

  # Extraer las medias
  media_clientes = df_clientes1.describe().loc["mean"]
  media_evasion = df_evasion1.describe().loc["mean"]


  plt.figure(figsize=(10, 6))
  plt.bar(media_clientes.index, media_clientes, color="skyblue", label="Media Clientes")
  plt.bar(media_evasion.index,media_evasion, color="red",  label="Media Evasión")

  # Agregar valores sobre los puntos
  for i, val in enumerate(media_clientes):
      plt.text(i, val + max(media_clientes.max(), media_evasion.max()) * 0.02, f"{val:,.0f}",
              ha='center', color='green')
  for i, val in enumerate(media_evasion):
      plt.text(i, val + max(media_clientes.max(), media_evasion.max()) * 0.02, f"{val:,.0f}",
              ha='center', color='red')

  plt.xlabel("Columna")
  plt.ylabel("Valor promedio de gasto")
  plt.title("Clientes vs Evasores")
  plt.legend()
  plt.grid(True, axis='y')
  plt.tight_layout()
  plt.savefig("/content/graf-media-tarifa.png", transparent=False, dpi=300, bbox_inches="tight")
  plt.show()

# %% [markdown]
# #📊 Carga y análisis

# %%
# Metricas

metricas = df.describe()
metricas
# Out:
#           Jubilado       Pareja        Hijos  Meses_de_Contrato  \
# count  7267.000000  7267.000000  7267.000000        7267.000000
# mean      0.162653     0.484106     0.300124          32.346498
# std       0.369074     0.499782     0.458343          24.571773
# min       0.000000     0.000000     0.000000           0.000000
# 25%       0.000000     0.000000     0.000000           9.000000
# 50%       0.000000     0.000000     0.000000          29.000000
# 75%       0.000000     1.000000     1.000000          55.000000
# max       1.000000     1.000000     1.000000          72.000000
#
#        Servicio_Telefónico  Multi_Lineas  Seguridad_Online  \
# count          7267.000000   7267.000000       7267.000000
# mean              0.902711      0.421770          0.285950
# std               0.296371      0.493876          0.451897
# min               0.000000      0.000000          0.000000
# 25%               1.000000      0.000000          0.000000
# ...

# %%
# Media de los datos de todos los clientes

media = metricas.loc["mean"]
media
# Out:
# Jubilado                      0.162653
# Pareja                        0.484106
# Hijos                         0.300124
# Meses_de_Contrato            32.346498
# Servicio_Telefónico           0.902711
# Multi_Lineas                  0.421770
# Seguridad_Online              0.285950
# Servicio_de_Backup            0.344571
# Proteccion_de_Dispositivo     0.342782
# Soporte_Tecnico_Full          0.289528
# Stream_TV                     0.383927
# Stream_Movies                 0.387505
# Factura_Online                0.593230
# Tarifa_Mensual_Cliente       64.720098
# Tarifa_por_Dia                2.157337
# Name: mean, dtype: float64

# %%
# Distribución de la variable Baja_cliente

baja_cliente = df["Baja_cliente"].value_counts()
baja_cliente
# Out:
# Baja_cliente
# 0    5174
# 1    1869
#       224
# Name: count, dtype: int64

# %%
baja_cliente_graf = baja_cliente.drop(index= "")
baja_cliente_graf
# Out:
# Baja_cliente
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
baja_cliente_graf = baja_cliente_graf.rename(index= {0: "Clientes", 1:"Baja de clientes"})
baja_cliente_graf
# Out:
# Baja_cliente
# Clientes            5174
# Baja de clientes    1869
# Name: count, dtype: int64

# %%
gen_graf_evasion("tab10")

# %%
gen_graf_evasion_GJHP('Set3')

# %%
gen_graf_evasion_Pagocontrato("Set3")

# %%
gen_graf_gastado3()

# %%
gen_graf_gastado_barras()

# %%
gen_graf_curva()

# %%
gen_graf_media_tarifa()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ## Introducción

# %% [markdown]
# La empresa Telecom X es proveedora de servicio de internet, televisión por cable y streaming. Está enfrentando una alta tasa de cancelación de suscripción al servicio por parte de sus clientes. Por lo tanto, decidió montar el proyecto "Churn de Clientes" o evasión de clientes, contratándome como asistente de análisis de datos para comprender los factores que llevan a la pérdida de clientes y reducción de ganancias, entre otros resultados que no favorecen a la empresa.

# %% [markdown]
# ## Limpieza y tratamiento de datos

# %% [markdown]
# ### Importación de datos

# %% [markdown]
# El primer paso realizado fue la importación de la base de datos provista por la empresa. Una vez descargada la base de datos y cargada a la plataforma de Google Colab (donde realizamos el tratamiento de los datos y el análisis). Fue guardada en una variable para poder ser transformada en un DataFrame, una estructura de datos trabajada por la biblioteca Pandas, y así poder ser manipulada.
#
# ```
# json = pd.read_json('/content/TelecomX_Data.json')
#
# json.head()
# ```
# Normalizado de la base de datos con formato json.
# ```
# import json
#
# with open('/content/TelecomX_Data.json', 'r', encoding='utf-8') as f:
#     data = json.load(f)
# ```
# ```
# df = pd.json_normalize(data)
# df
# ```
# Transformación de la base de datos a DataFrame para su limpieza y procesamiento.
# ```
# datos = pd.DataFrame(df)
# datos
# ```

# %% [markdown]
# El resultado de estas operaciones se puede apreciar en la siguiente tabla con 7267 filas y 21 columnas.

# %% [markdown]
# ![imagen_2025-06-18_150039454.png](data:image/png;base64,...)

# %% [markdown]
# ### Limpieza y procesamiento

# %% [markdown]
# La limpieza del archivo implicó la observación e identificación del tipo de datos obtenidos en el DataFrame para poder tener un panorama claro sobre la existencia o inexistencia de datos nulos en la base de datos obtenida.
# ```
# datos.info()
# ```

# %% [markdown]
# ![imagen_2025-06-18_150613662.png](data:image/png;base64,...)

# %% [markdown]
# Contemplando la lista que analiza los datos dentro de las 21 columnas, podemos observar que en las 7267 filas no se encontraron datos nulos y que, además, en las columnas donde había datos numéricos, los valores se clasifican con su tipo de dato correspondiente.
#
# Lo siguiente que se hizo fue normalizar los datos que aparecían como strings dentro de las columnas para que puedan ser contabilizados posteriormente. De esta forma, varias oraciones fueron reemplazadas con 0 y 1. Cero para los casos donde no posee o no tiene. Uno para los casos donde sí posee o no tiene la condición que presenta la columna.
# ```
# # Estandarización de datos
#
# columnas_a_convertir = ['Churn', 'customer.Partner', 'customer.Dependents', 'phone.PhoneService',
#                         'phone.MultipleLines','internet.OnlineSecurity','internet.OnlineBackup',
#                         'internet.DeviceProtection','internet.TechSupport','internet.StreamingTV',
#                         'internet.StreamingMovies','account.PaperlessBilling']
#
# df[columnas_a_convertir] = df[columnas_a_convertir].replace({'Yes': 1, 'No': 0, 'No internet service': 0, 'No phone service': 0})
#
# ```
#
# El resultado obtenido es el siguiente:

# %% [markdown]
# ![imagen_2025-06-18_162452276.png](data:image/png;base64,...)

# %% [markdown]
# Con los datos estandarizados, se analizó si la base de datos contenía inconsistencias en sus datos con las modificaciones realizadas.
# ```
# for col in df.columns:
#     print(f"Valores únicos en la columna '{col}':")
#     print(pd.unique(df[col]))
#     print('-' * 40)
# ```

# %% [markdown]
# ![imagen_2025-06-18_165246255.png](data:image/png;base64,...)

# %% [markdown]
# Con base en esta lista de valores únicos se realizó la transformación anterior de valores donde palabras fueron transformadas en 0 para casos negativos y 1 para valores positivos.
#
# Un proceso de transformación importante fue la traducción de parte de la base de datos, permitiendo un entendimiento mejor de la información que se estaba procesando y permitiendo un análisis más exhaustivo.
#
# ```
# # Obtener todos los nombres de las columnas para su traducción
# df_columnas = df.columns
# df_columnas
#
# ```
# Que muestra lo siguiente:

# %% [markdown]
# ![imagen_2025-06-18_180441581.png](data:image/png;base64,...)

# %% [markdown]
# Con esa lista de los nombres de las columnas se pudo traducir de la siguiente forma:
# ```
# df = df.rename(columns={
#     'customerID': "ID_cliente"
#     , 'Churn': "Baja_cliente"
#     , 'customer.gender': "Género"
#     , 'customer.SeniorCitizen': "Jubilado"
#     , 'customer.Partner': "Pareja"
#     , 'customer.Dependents': "Hijos"
#     , 'customer.tenure': "Meses_de_Contrato"
#     , 'phone.PhoneService': "Servicio_Telefónico"
#     , 'phone.MultipleLines': "Multi_Lineas"
#     , 'internet.InternetService': "Servicio_Internet"
#     , 'internet.OnlineSecurity': "Seguridad_Online"
#     , 'internet.OnlineBackup': "Servicio_de_Backup"
#     , 'internet.DeviceProtection': "Proteccion_de_Dispositivo"
#     , 'internet.TechSupport': "Soporte_Tecnico_Full"
#     , 'internet.StreamingTV': "Stream_TV"
#     , 'internet.StreamingMovies': "Stream_Movies"
#     , 'account.Contract': "Contrato"
#     , 'account.PaperlessBilling': "Factura_Online"
#     , 'account.PaymentMethod': "Forma_de_Pago"
#     , 'account.Charges.Monthly': "Tarifa_Mensual_Cliente"
#     , 'account.Charges.Total': "Total_Tarifas_Cliente"
#     , 'account.Charges.Daily': "Tarifa_por_Dia"
# })
# ```
#
# Mostrando el siguiente resultado:

# %% [markdown]
# ![imagen_2025-06-18_182300204.png](data:image/png;base64,...)

# %% [markdown]
# Ahora con la información más accesible y legible fue posible hacer el análisis exploratorio de los datos y sus indicadores.

# %% [markdown]
# ## Análisis exploratorio de Datos

# %% [markdown]
# Como primer punto de análisis, realicé una exploración de los datos contenidos en el DataFrame. El objetivo fue contabilizar y clasificar la información de los clientes para obtener métricas que nos permitan entender cómo se compone nuestra base de datos en función de las condiciones que presentan.

# %% [markdown]
# La siguiente imagen muestra un resumen de medias (promedios) de diferentes características de los clientes, como si están jubilados, si tienen pareja, hijos, meses de contrato, uso de servicios, etc. Por ejemplo, indica que un 16% de los clientes (total de clientes) se encuentra jubilado.
#
# ![imagen_2025-06-24_140400413.png](data:image/png;base64,...)

# %% [markdown]
# Luego, continúe con analizar qué cantidad de clientes se habían dado de baja y cuántos continuaban siendo usuarios. Contabilizando los 0 y 1 dentro del DataFrame, siendo el valor 1 para los clientes que se daban de baja.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Con la anterior información se dio forma a la siguiente situación que presenta la empresa. Donde un total de 1869 usuarios decidieron dejar de estar suscriptos a los servicios de la empresa.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Conociendo en concreto el número de clientes "evasores", realice el siguiente gráfico donde se puede observar cómo se reparten los clientes que se dieron de baja en función de los siguientes parámetros que se encuentran dentro del DataFrame:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para tener una visión más completa acerca de los perfiles con tendencia a la "evasión" de nuestros clientes, hice un análisis en función de la forma de pago preferida por estos y su tipo de contrato para el servicio.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Analizando los gastos tanto de "evasores" como de usuarios activos presentados en los siguientes gráficos. Se puede observar que los clientes que se han dado de baja han consumido menos servicios de los que la empresa ofrece que los usuarios activos. Resultando zonas más uniformes para el gráfico de barras verde que representa a los clientes activos.

# %% [markdown]
# ![imagen_2025-06-24_201143842.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para una visualización más clara de la diferencia de gastos entre "evasores" y clientes, podemos observar el siguiente gráfico de curva.

# %% [markdown]
# ![imagen_2025-06-24_205813551.png](data:image/png;base64,...)

# %% [markdown]
# Para finalizar el análisis de qué diferencias hay entre evasores y clientes podemos observar, el siguiente gráfico de medias de gastos entre ambos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Conclusiones e Insights

# %% [markdown]
# A partir del siguiente gráfico pude obtener varias conclusiones.

# %% [markdown]
# ![imagen_2025-06-24_211704999.png](data:image/png;base64,...)

# %% [markdown]
# Lo principal a destacar respecto al perfil obtenido de nuestros principales evasores, es el hecho de que el 75 % se encuentra en edad laboral, el 64% se encuentra soltero y el 82% no tiene hijos. El siguiente gráfico también nos da un indicio importante acerca del perfil de los evasores.

# %% [markdown]
# ![imagen_2025-06-24_212535731.png](data:image/png;base64,...)

# %% [markdown]
# Se puede apreciar que el 57% maneja pagos electrónicos y el 88%, prácticamente casi todos los evasores, tenían contratado un servicio mensual.
# Por lo tanto, se puede asumir que el perfil del cliente evasor es el de una persona en edad laboral, soltera, sin hijos, con conocimiento tecnológico y que prefiere un plan mensual (más flexible, menos compromiso). Probablemente, más independiente, busca control sobre su gasto y servicios.

# %% [markdown]
# ## Recomendaciones

# %% [markdown]
# *   Posibles estrategias para reducir la evasión.
#   * Ofrecer planes mensuales con beneficios escalables o personalizados, como acceso a velocidad extra de internet o mantenimiento full por fidelidad.
#   * Bonificación por continuidad del servicio. Ofrecer descuentos progresivos o beneficios acumulables sin necesidad de compromiso a largo plazo.
#   * Ofrecer paquetes personalizados de servicio. Brindar la posibilidad de que el cliente pueda desglosar los paquetes de servicio de entretenimiento o velocidad/mantenimiento enfocados.
#   * Ofrecer un plan para jubilados con descuento en el servicio de streaming y una campaña de mensajería. Donde le llegue al usuario semanalmente una lista con películas clásicas recomendadas para él.

# %% [markdown]
# **Muchas gracías por su atención!**
#
# Documento elaborado por: **Agustín Villalobos**
